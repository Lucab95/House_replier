# %%
import requests

api_key = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJub25jZSI6ImU1ZGIzZjc1LTAzN2QtNGEyZS1hYThhLWRhNzI2NTFmZDY5MCIsIm9yZ0lkIjoiNDI5NzExIiwidXNlcklkIjoiNDQyMDEyIiwidHlwZUlkIjoiMmU5NTg1N2EtZTZlMi00OTdjLWE4M2EtNzNjNWI3M2JhOTRmIiwidHlwZSI6IlBST0pFQ1QiLCJpYXQiOjE3Mzg3OTY4NjEsImV4cCI6NDg5NDU1Njg2MX0.VUWnB-NVW-wcgADkLOAtI2L4t7tlVl1LpbI5aRHSpcs'
from moralis import evm_api
body = {
  "tokens": [
    {
      "token_address": "0xdac17f958d2ee523a2206206994597c13d831ec7"
    },
    {
      "token_address": "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"
    },
    {
      "exchange": "uniswapv2",
      "token_address": "0xae7ab96520de3a18e5e111b5eaab095312d7fe84",
      "to_block": "16314545"
    },
    {
      "token_address": "0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0"
    }
  ]
}

params = {
  "chain": "eth",
  "include": "percent_change"
}

result = evm_api.token.get_multiple_token_prices(
  api_key=api_key,
  body=body,
  params=params,
)

print(result)
import pandas as pd

df = pd.DataFrame(result)

print(df)
df.head()
# Out:
# [{'tokenName': 'Tether USD', 'tokenSymbol': 'USDT', 'tokenLogo': 'https://logo.moralis.io/0x1_0xdac17f958d2ee523a2206206994597c13d831ec7_0b0d126af6c744c185e112a2c8dc1495.png', 'tokenDecimals': '6', 'nativePrice': {'value': '360159263737378', 'decimals': 18, 'name': 'Ether', 'symbol': 'ETH', 'address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'}, 'usdPrice': 0.9996198361564047, 'usdPriceFormatted': '0.999619836156404694', 'exchangeName': 'Uniswap v3', 'exchangeAddress': '0x1F98431c8aD98523631AE4a59f267346ea31F984', 'tokenAddress': '0xdac17f958d2ee523a2206206994597c13d831ec7', 'priceLastChangedAtBlock': '21783559', 'blockTimestamp': '1738797827000', 'possibleSpam': False, 'verifiedContract': True, 'pairAddress': '0xc7bbec68d12a0d1830360f8ec58fa599ba1b0e9b', 'pairTotalLiquidityUsd': '5369299.06', '24hrPercentChange': '-0.07451668895560662', 'securityScore': 41}, {'tokenName': 'USD Coin', 'tokenSymbol': 'USDC', 'tokenLogo': 'https://logo.moralis.io/0x1_0xa0b86991c6218b36c1d19d4a2e9eb0c
# ...

# %%
result
# Out:
# [{'tokenName': 'Tether USD',
#   'tokenSymbol': 'USDT',
#   'tokenLogo': 'https://logo.moralis.io/0x1_0xdac17f958d2ee523a2206206994597c13d831ec7_0b0d126af6c744c185e112a2c8dc1495.png',
#   'tokenDecimals': '6',
#   'nativePrice': {'value': '360159263737378',
#    'decimals': 18,
#    'name': 'Ether',
#    'symbol': 'ETH',
#    'address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2'},
#   'usdPrice': 0.9996198361564047,
#   'usdPriceFormatted': '0.999619836156404694',
#   'exchangeName': 'Uniswap v3',
#   'exchangeAddress': '0x1F98431c8aD98523631AE4a59f267346ea31F984',
#   'tokenAddress': '0xdac17f958d2ee523a2206206994597c13d831ec7',
#   'priceLastChangedAtBlock': '21783559',
#   'blockTimestamp': '1738797827000',
#   'possibleSpam': False,
#   'verifiedContract': True,
#   'pairAddress': '0xc7bbec68d12a0d1830360f8ec58fa599ba1b0e9b',
#   'pairTotalLiquidityUsd': '5369299.06',
#   '24hrPercentChange': '-0.07451668895560662',
#   'securityScore': 41},
#  {'tokenName': 'USD Coin',
# ...

# %%
# Dependencies to install:

# $ python -m pip install requests

import requests

timeframe = '5min'
url = f"https://deep-index.moralis.io/api/v2.2/pairs/0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640/ohlcv?chain=eth&timeframe={timeframe}&currency=usd&fromDate=2024-12-25&toDate=2025-01-01&cursor={cursor}"

headers = {
  "Accept": "application/json",
  "X-API-Key": api_key
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"message":"Invalid date input provided"}

# %%
cursor = response.json()['cursor']

print(cursor)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlIjoxLCJwYWlyQWRkcmVzcyI6IjB4ODhlNmEwYzJkZGQyNmZlZWI2NGYwMzlhMmM0MTI5NmZjYjNmNTY0MCIsInNwYW4iOjMwMCwidGltZXN0YW1wIjoiMTczNTY1OTYwMCIsImlhdCI6MTczODc5Nzg4NH0.R4UDwuuI1iJ3xOZzNTyROp84chmXSx-51AJXvXADA9o

# %%
response.json()
# Out:
# {'page': 1,
#  'cursor': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlIjoxLCJwYWlyQWRkcmVzcyI6IjB4ODhlNmEwYzJkZGQyNmZlZWI2NGYwMzlhMmM0MTI5NmZjYjNmNTY0MCIsInNwYW4iOjMwMCwidGltZXN0YW1wIjoiMTczNTY1OTYwMCIsImlhdCI6MTczODc5Nzg4NH0.R4UDwuuI1iJ3xOZzNTyROp84chmXSx-51AJXvXADA9o',
#  'pairAddress': '0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#  'tokenAddress': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#  'timeframe': '5min',
#  'currency': 'usd',
#  'result': [{'timestamp': '2024-12-31T23:55:00.000Z',
#    'open': 3334.0012130547766,
#    'high': 3334.0011611714895,
#    'low': 3332.3085462325184,
#    'close': 3339.699106848656,
#    'volume': 144947.7990848586,
#    'trades': 16},
#   {'timestamp': '2024-12-31T23:50:00.000Z',
#    'open': 3333.230792952279,
#    'high': 3334.2106044837606,
#    'low': 3332.639355946651,
#    'close': 3334.142145542047,
#    'volume': 204934.44908180778,
#    'trades': 15},
#   {'timestamp': '2024-12-31T23:45:00.000Z',
#    'open': 3330.7793448690986,
# ...

# %%
df = pd.DataFrame(response.json())

print(df)
df.head()
# Out:
#     page                                             cursor  \
# 0      1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 1      1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 2      1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 3      1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 4      1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# ..   ...                                                ...
# 95     1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 96     1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 97     1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 98     1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 99     1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
#
#                                    pairAddress  \
# 0   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# 1   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# 2   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# 3   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# ...

# %%
for index, row in df.iterrows():
    # convert timestamp to datetime
    df.at[index, 'result'] = pd.to_datetime(row['result']['timestamp'])

print(df)
df.head()
# Out:
#     page                                             cursor  \
# 0      1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 1      1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 2      1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 3      1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 4      1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# ..   ...                                                ...
# 95     1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 96     1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 97     1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 98     1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# 99     1  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
#
#                                    pairAddress  \
# 0   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# 1   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# 2   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# 3   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# ...

# %%
df.iloc[0]
# Out:
# page                                                            1
# cursor          eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJwYWdlI...
# pairAddress            0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# tokenAddress           0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# timeframe                                                    5min
# currency                                                      usd
# result                                  2024-12-31 23:55:00+00:00
# Name: 0, dtype: object
